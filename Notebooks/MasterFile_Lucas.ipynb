# %%
# Bring in current master file
import pandas as pd

# Read data from an Excel file
df = pd.read_excel('Master_Strain_10_11_2023.xlsx')

# %%
df.head()
# Out:
#   rating  universal_strain_id  brand breeder original_strain_name  \
# 0    NaN              1010041    NaN     NaN              $100 OG
# 1    NaN              1013505    NaN     NaN     Sergerbloom Haze
# 2    NaN              1013680    NaN     NaN          Sour Lemons
# 3    NaN              1014189    NaN     NaN     Wedding Cake MAC
# 4    NaN              1010793    NaN     NaN              Boss OG
#
#                             terpenes                    top_effects  \
# 0                                NaN  creative, euphoric, energetic
# 1                                NaN                            NaN
# 2                                NaN   euphoric, creative, uplifted
# 3  caryophyllene, humulene, limonene     aroused, focused, creative
# 4   myrcene, limonene, caryophyllene      giggly, creative, relaxed
#
#                                       effect_ratings  \
# 0                                                NaN
# ...

# %%
helloå
